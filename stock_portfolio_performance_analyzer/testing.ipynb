# %%
from data_fetcher import DataFetcher

# %%
import data_fetcher

a = data_fetcher.DataFetcher()
a.fetch_stock_data('PLTR', '2024-01-01', '2024-12-31')

# %%
import data_fetcher

b = data_fetcher.DataFetcher()
b.get_current_price('AAPL')

# %%
import data_fetcher

c = data_fetcher.DataFetcher()
c.get_stock_info('AMD')
# Out:
# {'name': 'Advanced Micro Devices, Inc.',
#  'sector': 'Technology',
#  'industry': 'Semiconductors',
#  'currency': 'USD'}

# %%
import data_fetcher

d = data_fetcher.DataFetcher()
d.fetch_market_data("^IXIC", "2024-01-01", "2024-12-31")
# Out:
# → Fetching data for ^IXIC from Yahoo Finance...
#                                    Open          High           Low  \
# Date
# 2024-01-02 00:00:00-05:00  14873.700195  14887.799805  14682.379883
# 2024-01-03 00:00:00-05:00  14641.469727  14694.580078  14577.440430
# 2024-01-04 00:00:00-05:00  14532.230469  14632.769531  14504.780273
# 2024-01-05 00:00:00-05:00  14500.110352  14625.190430  14477.570312
# 2024-01-08 00:00:00-05:00  14564.469727  14846.900391  14560.200195
# ...                                 ...           ...           ...
# 2024-12-23 00:00:00-05:00  19641.050781  19772.099609  19504.679688
# 2024-12-24 00:00:00-05:00  19818.480469  20031.130859  19813.759766
# 2024-12-26 00:00:00-05:00  19979.250000  20070.080078  19888.109375
# 2024-12-27 00:00:00-05:00  19896.769531  19904.769531  19553.400391
# 2024-12-30 00:00:00-05:00  19460.410156  19622.929688  19342.509766
#
#                                   Close      Volume  Dividends  Stock Splits
# Date
# ...
